# %%
import pandas as pd
df = pd.read_csv('/content/Std-001.csv')
df
domaincs = [programming fundamentals,Programming Fundamentals Lab Object Oriented Programming Lab,]
domaincssup =[English Composition & Comprehension Lab,	English Composition & Comprehension,Digital Logic Design,]

generaleducation = [Islamic Studies & Ethics,Pakistan Studies	]
mathematicsandsciencefoundation = [Applied Physics,Calculus & Analytical Geometry, Differential Equations	,  ]
# Out:
#     semester                                  courseName  creditHour grade  \
# 0          1                    Programming Fundamentals           3    C-
# 1          1     English Composition & Comprehension Lab           1     C
# 2          1                    Islamic Studies & Ethics           3     A
# 3          1                             Applied Physics           3     B
# 4          1              Calculus & Analytical Geometry           3     C
# 5          1         English Composition & Comprehension           3     C
# 6          1                Programming Fundamentals Lab           1    C+
# 7          2                      Differential Equations           3    A-
# 8          2                            Pakistan Studies           3    B+
# 9          2                        Digital Logic Design           3    B-
# 10         2             Object Oriented Programming Lab           1    B-
# ...

# %%
courses = {
    'Applied Physics': 'Mathematics & Science Foundation',
    'Calculus & Analytical Geometry': 'Mathematics & Science Foundation',
    'Differential Equations': 'Mathematics & Science Foundation',
    'Discrete Structures': 'Mathematics & Science Foundation',
    'Linear Algebra': 'Mathematics & Science Foundation',
    'Probability & Statistics': 'Mathematics & Science Foundation',
    'Programming Fundamentals': 'Computing – Core',
    'Programming Fundamentals Lab': 'Computing – Core',
    'Data Structures & Algorithms': 'Computing – Core',
    'Comp. Organization & Assembly Language': 'Computing – Core',
    'Comp. Organization & Assembly Language Lab': 'Computing – Core',
    'Design & Analysis of Algorithms': 'Computing – Core',
    'Digital Logic Design': 'Computing – Core',
    'Digital Logic Design Lab': 'Computing – Core',
    'Object-Oriented Programming': 'Computing – Core',
    'Object-Oriented Programming Lab': 'Computing – Core',
    'Operating Systems': 'Computing – Core',
    'Operating Systems Lab': 'Computing – Core',
    'Computer Networks': 'Computing – Core',
    'Computer Networks Lab': 'Computing – Core',
    'Software Engineering': 'Computing – Core',
    'Theory of Automata': 'Computing – Core',
    'Database Systems': 'Domain CS Core',
    'Database Systems Lab': 'Domain CS Core',
    'Domain CS Core': 'Domain CS Core',
    'Compiler Construction': 'Domain CS Electives',
    'Artificial Intelligence': 'Domain CS Electives',
    'Information Security': 'Domain CS Electives',
    'Communication & Presentation Skills': 'General Education',
    'English Composition & Comprehension': 'General Education',
    'English Composition & Comprehension Lab': 'General Education',
    'Islamic Studies & Ethics': 'General Education',
    'Pakistan Studies': 'General Education',
    'Technical & Business Writing': 'General Education',
    'Final Year Project': 'Domain CS Core',
    'Introduction to Info. & Comm. Technologies': 'Domain CS Electives',
    'Domain CS Supporting': 'Domain CS Supporting',
    'Economy Related': 'University Electives',
    'Social Science Related': 'University Electives',
}

# Organizing courses into domain lists
domain_lists = {
    'Mathematics & Science Foundation': [],
    'Computing – Core': [],
    'Domain CS Core': [],
    'Domain CS Electives': [],
    'General Education': [],
    'University Electives': [],
    'Domain CS Supporting': [],
}

# Populate domain lists
for course, domain in courses.items():
    domain_lists[domain].append(course)

# Print the organized lists
for domain, course_list in domain_lists.items():
    print(f'{domain} Courses:')
    for course in course_list:
        print(f'  - {course}')
    print()
# Out:
# Mathematics & Science Foundation Courses:
#   - Applied Physics
#   - Calculus & Analytical Geometry
#   - Differential Equations
#   - Discrete Structures
#   - Linear Algebra
#   - Probability & Statistics
#
# Computing – Core Courses:
#   - Programming Fundamentals
#   - Programming Fundamentals Lab
#   - Data Structures & Algorithms
#   - Comp. Organization & Assembly Language
#   - Comp. Organization & Assembly Language Lab
#   - Design & Analysis of Algorithms
#   - Digital Logic Design
#   - Digital Logic Design Lab
#   - Object-Oriented Programming
#   - Object-Oriented Programming Lab
#   - Operating Systems
#   - Operating Systems Lab
#   - Computer Networks
#   - Computer Networks Lab
#   - Software Engineering
#   - Theory of Automata
#
# Domain CS Core Courses:
#   - Database Systems
#   - Database Systems Lab
#   - Domain CS Core
#   - Final Year Project
#
# Domain CS Electives Courses:
#   - Compiler Construction
#   - Artificial Intelligence
# ...

# %%
import csv

# Define the courses dictionary
courses_dict = {
    'Applied Physics': 'Mathematics & Science Foundation',
    'Calculus & Analytical Geometry': 'Mathematics & Science Foundation',
      'Differential Equations': 'Mathematics & Science Foundation',
    'Discrete Structures': 'Mathematics & Science Foundation',
    'Linear Algebra': 'Mathematics & Science Foundation',
    'Probability & Statistics': 'Mathematics & Science Foundation',
    'Programming Fundamentals': 'Computing – Core',
    'Programming Fundamentals Lab': 'Computing – Core',
    'Data Structures & Algorithms': 'Computing – Core',
    'Comp. Organization & Assembly Language': 'Computing – Core',
    'Comp. Organization & Assembly Language Lab': 'Computing – Core',
    'Design & Analysis of Algorithms': 'Computing – Core',
    'Digital Logic Design': 'Computing – Core',
    'Digital Logic Design Lab': 'Computing – Core',
    'Object-Oriented Programming': 'Computing – Core',
    'Object-Oriented Programming Lab': 'Computing – Core',
    'Operating Systems': 'Computing – Core',
    'Operating Systems Lab': 'Computing – Core',
    'Computer Networks': 'Computing – Core',
    'Computer Networks Lab': 'Computing – Core',
    'Software Engineering': 'Computing – Core',
    'Theory of Automata': 'Computing – Core',
    'Database Systems': 'Domain CS Core',
    'Database Systems Lab': 'Domain CS Core',
    'Domain CS Core': 'Domain CS Core',
    'Compiler Construction': 'Domain CS Electives',
    'Artificial Intelligence': 'Domain CS Electives',
    'Information Security': 'Domain CS Electives',
    'Communication & Presentation Skills': 'General Education',
    'English Composition & Comprehension': 'General Education',
    'English Composition & Comprehension Lab': 'General Education',
    'Islamic Studies & Ethics': 'General Education',
    'Pakistan Studies': 'General Education',
    'Technical & Business Writing': 'General Education',
    'Final Year Project': 'Domain CS Core',
    'Introduction to Info. & Comm. Technologies': 'Domain CS Electives',
    'Domain CS Supporting': 'Domain CS Supporting',
    'Economy Related': 'University Electives',
    'Social Science Related': 'University Electives',

}

# Read the new CSV file (replace 'new_courses.csv' with the actual filename)
new_csv_filename = '/content/Std-001.csv'
new_courses = []

with open(new_csv_filename, 'r') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        new_courses.append(row['courseName'])

# Calculate the percentage for each domain
total_courses = len(new_courses)
domain_counts = {domain: new_courses.count(course) for course, domain in courses_dict.items()}

# Check the percentage criteria
common_courses_percentage = (domain_counts['General Education'] + domain_counts['University Electives'] +
                             domain_counts['Mathematics & Science Foundation'] + domain_counts['Computing – Core']) / total_courses * 100

domain_courses_percentage = (domain_counts['Domain CS Core'] + domain_counts['Domain CS Electives'] +
                             domain_counts['Domain CS Supporting']) / total_courses * 100

# Print the results
print(f'Common Courses Percentage: {common_courses_percentage}%')
print(f'Domain Courses Percentage: {domain_courses_percentage}%')

# Check pass/fail criteria
if (common_courses_percentage >= 63) and (domain_courses_percentage >= 37):
    print('You are pass')
else:
    print('You are not pass')
# Out:
# Common Courses Percentage: 8.16326530612245%
# Domain Courses Percentage: 8.16326530612245%
# You are not pass
